# %% [markdown]
# # Test the Image

# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)
# path="/content/drive/My Drive/Alexnet/img/an2i/an2i_up_sad_sunglasses.pgm"
# import cv2
# img= cv2.imread(path, 0)
# from google.colab.patches import cv2_imshow
# cv2_imshow(img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# path_2="/content/drive/My Drive/Alexnet/img/sz24/sz24_up_sad_sunglasses.pgm"
# img_2= cv2.imread(path_2, 0)
# cv2_imshow(img_2)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# # Library

# %%
import types
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import shutil
import os
from google.colab import drive
import glob
import fnmatch

# %% [markdown]
# # Load Dataset

# %%
drive.mount('/content/gdrive', force_remount = True)
root_dir = '/content/gdrive/My Drive/Alexnet/'
data_dir = root_dir + 'img2'
train_dir = root_dir + 'img2/train/'
val_dir = root_dir + 'img2/val'
os.listdir(data_dir)
# Out:
# Mounted at /content/gdrive
# ['an2i',
#  'boland',
#  'at33',
#  'danieln',
#  'glickman',
#  'cheyer',
#  'choon',
#  'ch4f',
#  'bpm',
#  'karyadi',
#  'mitchell',
#  'kawamura',
#  'phoebe',
#  'kk49',
#  'megak',
#  'sz24',
#  'night',
#  'saavik',
#  'steffi',
#  'tammo']

# %%
# pip install Pillow

# %%
# import os
# from PIL import Image

# for file in os.listdir("/content/gdrive/My Drive/Alexnet/img/tammo"):
#     filename, extension  = os.path.splitext(file)
#     if extension == ".pgm":
#         new_file = "{}.jpg".format(filename)
#         with Image.open("/content/gdrive/My Drive/Alexnet/img/tammo/"+file) as im:
#             im.save("/content/gdrive/My Drive/Alexnet/img2/tammo" + new_file)

# %%
# import os
# import PIL
# from PIL import Image

# for file in os.listdir("/content/gdrive/My Drive/Alexnet/img/tammo"):
#     filename, extension  = os.path.splitext(file)
#     if extension == ".pgm":
#         new_file = "{}.jpg".format(filename)
#         try:
#           with Image.open("/content/gdrive/My Drive/Alexnet/img/tammo/"+file) as im:
#               im.save("/content/gdrive/My Drive/Alexnet/img2/tammo/" + new_file)
#         except PIL.UnidentifiedImageError:
#           print("/content/gdrive/My Drive/Alexnet/img/tammo/"+file)

# %%
# import glob
# from PIL import Image
# for file in glob.iglob("/content/gdrive/My Drive/Alexnet/img/**", recursive=True):
#   filename, extension  = os.path.splitext(file)
#   if extension == ".pgm":
#     new_file = "{}.jpg".format(filename)
#     with Image.open(file) as im:
#       im.save("/content/gdrive/My Drive/Alexnet/img2/**" + new_file)

# %% [markdown]
# # Check Existing Directory

# %%
train_path = "/content/gdrive/My Drive/Alexnet/img2/train"
isExistTrain = os.path.exists(train_path)
val_path = "/content/gdrive/My Drive/Alexnet/img2/val"
isExistVal = os.path.exists(val_path)

if not isExistTrain:
  os.mkdir(train_path)
if not isExistVal:
  os.mkdir(val_path)

# %%
left_train_path = "/content/gdrive/My Drive/Alexnet/img2/train/left_train"
isExistLeft = os.path.exists(left_train_path)
right_train_path = "/content/gdrive/My Drive/Alexnet/img2/train/right_train"
isExistRight = os.path.exists(right_train_path)
up_train_path = "/content/gdrive/My Drive/Alexnet/img2/train/up_train"
isExistUp = os.path.exists(up_train_path)
straight_train_path = "/content/gdrive/My Drive/Alexnet/img2/train/straight_train"
isExistStraight = os.path.exists(straight_train_path)

if not isExistLeft:
  os.mkdir(left_train_path)
if not isExistRight:
  os.mkdir(right_train_path)
if not isExistUp:
  os.mkdir(up_train_path)
if not isExistStraight:
  os.mkdir(straight_train_path)

# %%
left_val_path = "/content/gdrive/My Drive/Alexnet/img2/val/left_val"
isExistLeft = os.path.exists(left_val_path)
right_val_path = "/content/gdrive/My Drive/Alexnet/img2/val/right_val"
isExistRight = os.path.exists(right_val_path)
up_val_path = "/content/gdrive/My Drive/Alexnet/img2/val/up_val"
isExistUp = os.path.exists(up_val_path)
straight_val_path = "/content/gdrive/My Drive/Alexnet/img2/val/straight_val"
isExistStraight = os.path.exists(straight_val_path)

if not isExistLeft:
  os.mkdir(left_val_path)
if not isExistRight:
  os.mkdir(right_val_path)
if not isExistUp:
  os.mkdir(up_val_path)
if not isExistStraight:
  os.mkdir(straight_val_path)

# %% [markdown]
# # Left

# %%
array_tammo = []
dir_tammo = os.listdir('/content/gdrive/My Drive/Alexnet/img2/tammo')
pattern = "tammo_left*.jpg"
for filename in dir_tammo:
  if fnmatch.fnmatch(filename,pattern):
    array_tammo.append(filename)
left_train_tammo,left_val_tammo = train_test_split(array_tammo,test_size = 0.4,random_state=42)

array_sz24 = []
dir_sz24 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/sz24')
pattern = "sz24_left*.jpg"
for filename in dir_sz24:
  if fnmatch.fnmatch(filename,pattern):
    array_sz24.append(filename)
left_train_sz24,left_val_sz24 = train_test_split(array_sz24,test_size = 0.4,random_state=42)

array_steffi = []
dir_steffi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/steffi')
pattern = "steffi_left*.jpg"
for filename in dir_steffi:
  if fnmatch.fnmatch(filename,pattern):
    array_steffi.append(filename)
left_train_steffi,left_val_steffi = train_test_split(array_steffi,test_size = 0.4,random_state=42)

array_saavik = []
dir_saavik = os.listdir('/content/gdrive/My Drive/Alexnet/img2/saavik')
pattern = "saavik_left*.jpg"
for filename in dir_saavik:
  if fnmatch.fnmatch(filename,pattern):
    array_saavik.append(filename)
left_train_saavik,left_val_saavik = train_test_split(array_saavik,test_size = 0.4,random_state=42)

array_phoebe = []
dir_phoebe = os.listdir('/content/gdrive/My Drive/Alexnet/img2/phoebe')
pattern = "phoebe_left*.jpg"
for filename in dir_phoebe:
  if fnmatch.fnmatch(filename,pattern):
    array_phoebe.append(filename)
left_train_phoebe,left_val_phoebe = train_test_split(array_phoebe,test_size = 0.4,random_state=42)

array_night = []
dir_night = os.listdir('/content/gdrive/My Drive/Alexnet/img2/night')
pattern = "night_left*.jpg"
for filename in dir_night:
  if fnmatch.fnmatch(filename,pattern):
    array_night.append(filename)
left_train_night,left_val_night = train_test_split(array_night,test_size = 0.4,random_state=42)

array_mitchell = []
dir_mitchell = os.listdir('/content/gdrive/My Drive/Alexnet/img2/mitchell')
pattern = "mitchell_left*.jpg"
for filename in dir_mitchell:
  if fnmatch.fnmatch(filename,pattern):
    array_mitchell.append(filename)
left_train_mitchell,left_val_mitchell = train_test_split(array_mitchell,test_size = 0.4,random_state=42)

array_megak = []
dir_megak = os.listdir('/content/gdrive/My Drive/Alexnet/img2/megak')
pattern = "megak_left*.jpg"
for filename in dir_megak:
  if fnmatch.fnmatch(filename,pattern):
    array_megak.append(filename)
left_train_megak,left_val_megak = train_test_split(array_megak,test_size = 0.4,random_state=42)

array_kk49 = []
dir_kk49 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kk49')
pattern = "kk49_left*.jpg"
for filename in dir_kk49:
  if fnmatch.fnmatch(filename,pattern):
    array_kk49.append(filename)
left_train_kk49,left_val_kk49 = train_test_split(array_kk49,test_size = 0.4,random_state=42)

array_kawamura = []
dir_kawamura = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kawamura')
pattern = "kawamura_left*.jpg"
for filename in dir_kawamura:
  if fnmatch.fnmatch(filename,pattern):
    array_kawamura.append(filename)
left_train_kawamura,left_val_kawamura = train_test_split(array_kawamura,test_size = 0.4,random_state=42)

array_karyadi = []
dir_karyadi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/karyadi')
pattern = "karyadi_left*.jpg"
for filename in dir_karyadi:
  if fnmatch.fnmatch(filename,pattern):
    array_karyadi.append(filename)
left_train_karyadi,left_val_karyadi = train_test_split(array_karyadi,test_size = 0.4,random_state=42)

array_glickman = []
dir_glickman = os.listdir('/content/gdrive/My Drive/Alexnet/img2/glickman')
pattern = "glickman_left*.jpg"
for filename in dir_glickman:
  if fnmatch.fnmatch(filename,pattern):
    array_glickman.append(filename)
left_train_glickman,left_val_glickman = train_test_split(array_glickman,test_size = 0.4,random_state=42)

array_danieln = []
dir_danieln = os.listdir('/content/gdrive/My Drive/Alexnet/img2/danieln')
pattern = "danieln_left*.jpg"
for filename in dir_danieln:
  if fnmatch.fnmatch(filename,pattern):
    array_danieln.append(filename)
left_train_danieln,left_val_danieln = train_test_split(array_danieln,test_size = 0.4,random_state=42)

array_choon = []
dir_choon = os.listdir('/content/gdrive/My Drive/Alexnet/img2/choon')
pattern = "choon_left*.jpg"
for filename in dir_choon:
  if fnmatch.fnmatch(filename,pattern):
    array_choon.append(filename)
left_train_choon,left_val_choon = train_test_split(array_choon,test_size = 0.4,random_state=42)

array_cheyer = []
dir_cheyer = os.listdir('/content/gdrive/My Drive/Alexnet/img2/cheyer')
pattern = "cheyer_left*.jpg"
for filename in dir_cheyer:
  if fnmatch.fnmatch(filename,pattern):
    array_cheyer.append(filename)
left_train_cheyer,left_val_cheyer = train_test_split(array_cheyer,test_size = 0.4,random_state=42)

array_ch4f = []
dir_ch4f = os.listdir('/content/gdrive/My Drive/Alexnet/img2/ch4f')
pattern = "ch4f_left*.jpg"
for filename in dir_ch4f:
  if fnmatch.fnmatch(filename,pattern):
    array_ch4f.append(filename)
left_train_ch4f,left_val_ch4f = train_test_split(array_ch4f,test_size = 0.4,random_state=42)

array_bpm = []
dir_bpm = os.listdir('/content/gdrive/My Drive/Alexnet/img2/bpm')
pattern = "bpm_left*.jpg"
for filename in dir_bpm:
  if fnmatch.fnmatch(filename,pattern):
    array_bpm.append(filename)
left_train_bpm,left_val_bpm = train_test_split(array_bpm,test_size = 0.4,random_state=42)

array_boland = []
dir_boland = os.listdir('/content/gdrive/My Drive/Alexnet/img2/boland')
pattern = "boland_left*.jpg"
for filename in dir_boland:
  if fnmatch.fnmatch(filename,pattern):
    array_boland.append(filename)
left_train_boland,left_val_boland = train_test_split(array_boland,test_size = 0.4,random_state=42)

array_at33 = []
dir_at33 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/at33')
pattern = "at33_left*.jpg"
for filename in dir_at33:
  if fnmatch.fnmatch(filename,pattern):
    array_at33.append(filename)
left_train_at33,left_val_at33 = train_test_split(array_at33,test_size = 0.4,random_state=42)

array_an2i = []
dir_an2i = os.listdir('/content/gdrive/My Drive/Alexnet/img2/an2i')
pattern = "an2i_left*.jpg"
for filename in dir_an2i:
  if fnmatch.fnmatch(filename,pattern):
    array_an2i.append(filename)
left_train_an2i,left_val_an2i = train_test_split(array_an2i,test_size = 0.4,random_state=42)

# %%
for i in left_train_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(train_dir + '/left_train', i))
for i in left_train_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(train_dir + '/left_train', i))

# %%
for i in left_val_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(val_dir + '/left_val', i))
for i in left_val_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(val_dir + '/left_val', i))

# %% [markdown]
# # Right

# %%
array_tammo = []
dir_tammo = os.listdir('/content/gdrive/My Drive/Alexnet/img2/tammo')
pattern = "tammo_right*.jpg"
for filename in dir_tammo:
  if fnmatch.fnmatch(filename,pattern):
    array_tammo.append(filename)
right_train_tammo,right_val_tammo = train_test_split(array_tammo,test_size = 0.4,random_state=42)

array_sz24 = []
dir_sz24 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/sz24')
pattern = "sz24_right*.jpg"
for filename in dir_sz24:
  if fnmatch.fnmatch(filename,pattern):
    array_sz24.append(filename)
right_train_sz24,right_val_sz24 = train_test_split(array_sz24,test_size = 0.4,random_state=42)

array_steffi = []
dir_steffi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/steffi')
pattern = "steffi_right*.jpg"
for filename in dir_steffi:
  if fnmatch.fnmatch(filename,pattern):
    array_steffi.append(filename)
right_train_steffi,right_val_steffi = train_test_split(array_steffi,test_size = 0.4,random_state=42)

array_saavik = []
dir_saavik = os.listdir('/content/gdrive/My Drive/Alexnet/img2/saavik')
pattern = "saavik_right*.jpg"
for filename in dir_saavik:
  if fnmatch.fnmatch(filename,pattern):
    array_saavik.append(filename)
right_train_saavik,right_val_saavik = train_test_split(array_saavik,test_size = 0.4,random_state=42)

array_phoebe = []
dir_phoebe = os.listdir('/content/gdrive/My Drive/Alexnet/img2/phoebe')
pattern = "phoebe_right*.jpg"
for filename in dir_phoebe:
  if fnmatch.fnmatch(filename,pattern):
    array_phoebe.append(filename)
right_train_phoebe,right_val_phoebe = train_test_split(array_phoebe,test_size = 0.4,random_state=42)

array_night = []
dir_night = os.listdir('/content/gdrive/My Drive/Alexnet/img2/night')
pattern = "night_right*.jpg"
for filename in dir_night:
  if fnmatch.fnmatch(filename,pattern):
    array_night.append(filename)
right_train_night,right_val_night = train_test_split(array_night,test_size = 0.4,random_state=42)

array_mitchell = []
dir_mitchell = os.listdir('/content/gdrive/My Drive/Alexnet/img2/mitchell')
pattern = "mitchell_right*.jpg"
for filename in dir_mitchell:
  if fnmatch.fnmatch(filename,pattern):
    array_mitchell.append(filename)
right_train_mitchell,right_val_mitchell = train_test_split(array_mitchell,test_size = 0.4,random_state=42)

array_megak = []
dir_megak = os.listdir('/content/gdrive/My Drive/Alexnet/img2/megak')
pattern = "megak_right*.jpg"
for filename in dir_megak:
  if fnmatch.fnmatch(filename,pattern):
    array_megak.append(filename)
right_train_megak,right_val_megak = train_test_split(array_megak,test_size = 0.4,random_state=42)

array_kk49 = []
dir_kk49 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kk49')
pattern = "kk49_right*.jpg"
for filename in dir_kk49:
  if fnmatch.fnmatch(filename,pattern):
    array_kk49.append(filename)
right_train_kk49,right_val_kk49 = train_test_split(array_kk49,test_size = 0.4,random_state=42)

array_kawamura = []
dir_kawamura = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kawamura')
pattern = "kawamura_right*.jpg"
for filename in dir_kawamura:
  if fnmatch.fnmatch(filename,pattern):
    array_kawamura.append(filename)
right_train_kawamura,right_val_kawamura = train_test_split(array_kawamura,test_size = 0.4,random_state=42)

array_karyadi = []
dir_karyadi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/karyadi')
pattern = "karyadi_right*.jpg"
for filename in dir_karyadi:
  if fnmatch.fnmatch(filename,pattern):
    array_karyadi.append(filename)
right_train_karyadi,right_val_karyadi = train_test_split(array_karyadi,test_size = 0.4,random_state=42)

array_glickman = []
dir_glickman = os.listdir('/content/gdrive/My Drive/Alexnet/img2/glickman')
pattern = "glickman_right*.jpg"
for filename in dir_glickman:
  if fnmatch.fnmatch(filename,pattern):
    array_glickman.append(filename)
right_train_glickman,right_val_glickman = train_test_split(array_glickman,test_size = 0.4,random_state=42)

array_danieln = []
dir_danieln = os.listdir('/content/gdrive/My Drive/Alexnet/img2/danieln')
pattern = "danieln_right*.jpg"
for filename in dir_danieln:
  if fnmatch.fnmatch(filename,pattern):
    array_danieln.append(filename)
right_train_danieln,right_val_danieln = train_test_split(array_danieln,test_size = 0.4,random_state=42)

array_choon = []
dir_choon = os.listdir('/content/gdrive/My Drive/Alexnet/img2/choon')
pattern = "choon_right*.jpg"
for filename in dir_choon:
  if fnmatch.fnmatch(filename,pattern):
    array_choon.append(filename)
right_train_choon,right_val_choon = train_test_split(array_choon,test_size = 0.4,random_state=42)

array_cheyer = []
dir_cheyer = os.listdir('/content/gdrive/My Drive/Alexnet/img2/cheyer')
pattern = "cheyer_right*.jpg"
for filename in dir_cheyer:
  if fnmatch.fnmatch(filename,pattern):
    array_cheyer.append(filename)
right_train_cheyer,right_val_cheyer = train_test_split(array_cheyer,test_size = 0.4,random_state=42)

array_ch4f = []
dir_ch4f = os.listdir('/content/gdrive/My Drive/Alexnet/img2/ch4f')
pattern = "ch4f_right*.jpg"
for filename in dir_ch4f:
  if fnmatch.fnmatch(filename,pattern):
    array_ch4f.append(filename)
right_train_ch4f,right_val_ch4f = train_test_split(array_ch4f,test_size = 0.4,random_state=42)

array_bpm = []
dir_bpm = os.listdir('/content/gdrive/My Drive/Alexnet/img2/bpm')
pattern = "bpm_right*.jpg"
for filename in dir_bpm:
  if fnmatch.fnmatch(filename,pattern):
    array_bpm.append(filename)
right_train_bpm,right_val_bpm = train_test_split(array_bpm,test_size = 0.4,random_state=42)

array_boland = []
dir_boland = os.listdir('/content/gdrive/My Drive/Alexnet/img2/boland')
pattern = "boland_right*.jpg"
for filename in dir_boland:
  if fnmatch.fnmatch(filename,pattern):
    array_boland.append(filename)
right_train_boland,right_val_boland = train_test_split(array_boland,test_size = 0.4,random_state=42)

array_at33 = []
dir_at33 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/at33')
pattern = "at33_right*.jpg"
for filename in dir_at33:
  if fnmatch.fnmatch(filename,pattern):
    array_at33.append(filename)
right_train_at33,right_val_at33 = train_test_split(array_at33,test_size = 0.4,random_state=42)

array_an2i = []
dir_an2i = os.listdir('/content/gdrive/My Drive/Alexnet/img2/an2i')
pattern = "an2i_right*.jpg"
for filename in dir_an2i:
  if fnmatch.fnmatch(filename,pattern):
    array_an2i.append(filename)
right_train_an2i,right_val_an2i = train_test_split(array_an2i,test_size = 0.4,random_state=42)

# %%
for i in right_train_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(train_dir + '/right_train', i))
for i in right_train_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(train_dir + '/right_train', i))

# %%
for i in right_val_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(val_dir + '/right_val', i))
for i in right_val_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(val_dir + '/right_val', i))

# %% [markdown]
# # Up

# %%
array_tammo = []
dir_tammo = os.listdir('/content/gdrive/My Drive/Alexnet/img2/tammo')
pattern = "tammo_up*.jpg"
for filename in dir_tammo:
  if fnmatch.fnmatch(filename,pattern):
    array_tammo.append(filename)
up_train_tammo,up_val_tammo = train_test_split(array_tammo,test_size = 0.4,random_state=42)

array_sz24 = []
dir_sz24 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/sz24')
pattern = "sz24_up*.jpg"
for filename in dir_sz24:
  if fnmatch.fnmatch(filename,pattern):
    array_sz24.append(filename)
up_train_sz24,up_val_sz24 = train_test_split(array_sz24,test_size = 0.4,random_state=42)

array_steffi = []
dir_steffi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/steffi')
pattern = "steffi_up*.jpg"
for filename in dir_steffi:
  if fnmatch.fnmatch(filename,pattern):
    array_steffi.append(filename)
up_train_steffi,up_val_steffi = train_test_split(array_steffi,test_size = 0.4,random_state=42)

array_saavik = []
dir_saavik = os.listdir('/content/gdrive/My Drive/Alexnet/img2/saavik')
pattern = "saavik_up*.jpg"
for filename in dir_saavik:
  if fnmatch.fnmatch(filename,pattern):
    array_saavik.append(filename)
up_train_saavik,up_val_saavik = train_test_split(array_saavik,test_size = 0.4,random_state=42)

array_phoebe = []
dir_phoebe = os.listdir('/content/gdrive/My Drive/Alexnet/img2/phoebe')
pattern = "phoebe_up*.jpg"
for filename in dir_phoebe:
  if fnmatch.fnmatch(filename,pattern):
    array_phoebe.append(filename)
up_train_phoebe,up_val_phoebe = train_test_split(array_phoebe,test_size = 0.4,random_state=42)

array_night = []
dir_night = os.listdir('/content/gdrive/My Drive/Alexnet/img2/night')
pattern = "night_up*.jpg"
for filename in dir_night:
  if fnmatch.fnmatch(filename,pattern):
    array_night.append(filename)
up_train_night,up_val_night = train_test_split(array_night,test_size = 0.4,random_state=42)

array_mitchell = []
dir_mitchell = os.listdir('/content/gdrive/My Drive/Alexnet/img2/mitchell')
pattern = "mitchell_up*.jpg"
for filename in dir_mitchell:
  if fnmatch.fnmatch(filename,pattern):
    array_mitchell.append(filename)
up_train_mitchell,up_val_mitchell = train_test_split(array_mitchell,test_size = 0.4,random_state=42)

array_megak = []
dir_megak = os.listdir('/content/gdrive/My Drive/Alexnet/img2/megak')
pattern = "megak_up*.jpg"
for filename in dir_megak:
  if fnmatch.fnmatch(filename,pattern):
    array_megak.append(filename)
up_train_megak,up_val_megak = train_test_split(array_megak,test_size = 0.4,random_state=42)

array_kk49 = []
dir_kk49 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kk49')
pattern = "kk49_up*.jpg"
for filename in dir_kk49:
  if fnmatch.fnmatch(filename,pattern):
    array_kk49.append(filename)
up_train_kk49,up_val_kk49 = train_test_split(array_kk49,test_size = 0.4,random_state=42)

array_kawamura = []
dir_kawamura = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kawamura')
pattern = "kawamura_up*.jpg"
for filename in dir_kawamura:
  if fnmatch.fnmatch(filename,pattern):
    array_kawamura.append(filename)
up_train_kawamura,up_val_kawamura = train_test_split(array_kawamura,test_size = 0.4,random_state=42)

array_karyadi = []
dir_karyadi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/karyadi')
pattern = "karyadi_up*.jpg"
for filename in dir_karyadi:
  if fnmatch.fnmatch(filename,pattern):
    array_karyadi.append(filename)
up_train_karyadi,up_val_karyadi = train_test_split(array_karyadi,test_size = 0.4,random_state=42)

array_glickman = []
dir_glickman = os.listdir('/content/gdrive/My Drive/Alexnet/img2/glickman')
pattern = "glickman_up*.jpg"
for filename in dir_glickman:
  if fnmatch.fnmatch(filename,pattern):
    array_glickman.append(filename)
up_train_glickman,up_val_glickman = train_test_split(array_glickman,test_size = 0.4,random_state=42)

array_danieln = []
dir_danieln = os.listdir('/content/gdrive/My Drive/Alexnet/img2/danieln')
pattern = "danieln_up*.jpg"
for filename in dir_danieln:
  if fnmatch.fnmatch(filename,pattern):
    array_danieln.append(filename)
up_train_danieln,up_val_danieln = train_test_split(array_danieln,test_size = 0.4,random_state=42)

array_choon = []
dir_choon = os.listdir('/content/gdrive/My Drive/Alexnet/img2/choon')
pattern = "choon_up*.jpg"
for filename in dir_choon:
  if fnmatch.fnmatch(filename,pattern):
    array_choon.append(filename)
up_train_choon,up_val_choon = train_test_split(array_choon,test_size = 0.4,random_state=42)

array_cheyer = []
dir_cheyer = os.listdir('/content/gdrive/My Drive/Alexnet/img2/cheyer')
pattern = "cheyer_up*.jpg"
for filename in dir_cheyer:
  if fnmatch.fnmatch(filename,pattern):
    array_cheyer.append(filename)
up_train_cheyer,up_val_cheyer = train_test_split(array_cheyer,test_size = 0.4,random_state=42)

array_ch4f = []
dir_ch4f = os.listdir('/content/gdrive/My Drive/Alexnet/img2/ch4f')
pattern = "ch4f_up*.jpg"
for filename in dir_ch4f:
  if fnmatch.fnmatch(filename,pattern):
    array_ch4f.append(filename)
up_train_ch4f,up_val_ch4f = train_test_split(array_ch4f,test_size = 0.4,random_state=42)

array_bpm = []
dir_bpm = os.listdir('/content/gdrive/My Drive/Alexnet/img2/bpm')
pattern = "bpm_up*.jpg"
for filename in dir_bpm:
  if fnmatch.fnmatch(filename,pattern):
    array_bpm.append(filename)
up_train_bpm,up_val_bpm = train_test_split(array_bpm,test_size = 0.4,random_state=42)

array_boland = []
dir_boland = os.listdir('/content/gdrive/My Drive/Alexnet/img2/boland')
pattern = "boland_up*.jpg"
for filename in dir_boland:
  if fnmatch.fnmatch(filename,pattern):
    array_boland.append(filename)
up_train_boland,up_val_boland = train_test_split(array_boland,test_size = 0.4,random_state=42)

array_at33 = []
dir_at33 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/at33')
pattern = "at33_up*.jpg"
for filename in dir_at33:
  if fnmatch.fnmatch(filename,pattern):
    array_at33.append(filename)
up_train_at33,up_val_at33 = train_test_split(array_at33,test_size = 0.4,random_state=42)

array_an2i = []
dir_an2i = os.listdir('/content/gdrive/My Drive/Alexnet/img2/an2i')
pattern = "an2i_up*.jpg"
for filename in dir_an2i:
  if fnmatch.fnmatch(filename,pattern):
    array_an2i.append(filename)
up_train_an2i,up_val_an2i = train_test_split(array_an2i,test_size = 0.4,random_state=42)

# %%
for i in up_train_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(train_dir + '/up_train', i))
for i in up_train_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(train_dir + '/up_train', i))

# %%
for i in up_val_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(val_dir + '/up_val', i))
for i in up_val_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(val_dir + '/up_val', i))

# %% [markdown]
# # Straight

# %%
array_tammo = []
dir_tammo = os.listdir('/content/gdrive/My Drive/Alexnet/img2/tammo')
pattern = "tammo_straight*.jpg"
for filename in dir_tammo:
  if fnmatch.fnmatch(filename,pattern):
    array_tammo.append(filename)
straight_train_tammo,straight_val_tammo = train_test_split(array_tammo,test_size = 0.4,random_state=42)

array_sz24 = []
dir_sz24 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/sz24')
pattern = "sz24_straight*.jpg"
for filename in dir_sz24:
  if fnmatch.fnmatch(filename,pattern):
    array_sz24.append(filename)
straight_train_sz24,straight_val_sz24 = train_test_split(array_sz24,test_size = 0.4,random_state=42)

array_steffi = []
dir_steffi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/steffi')
pattern = "steffi_straight*.jpg"
for filename in dir_steffi:
  if fnmatch.fnmatch(filename,pattern):
    array_steffi.append(filename)
straight_train_steffi,straight_val_steffi = train_test_split(array_steffi,test_size = 0.4,random_state=42)

array_saavik = []
dir_saavik = os.listdir('/content/gdrive/My Drive/Alexnet/img2/saavik')
pattern = "saavik_straight*.jpg"
for filename in dir_saavik:
  if fnmatch.fnmatch(filename,pattern):
    array_saavik.append(filename)
straight_train_saavik,straight_val_saavik = train_test_split(array_saavik,test_size = 0.4,random_state=42)

array_phoebe = []
dir_phoebe = os.listdir('/content/gdrive/My Drive/Alexnet/img2/phoebe')
pattern = "phoebe_straight*.jpg"
for filename in dir_phoebe:
  if fnmatch.fnmatch(filename,pattern):
    array_phoebe.append(filename)
straight_train_phoebe,straight_val_phoebe = train_test_split(array_phoebe,test_size = 0.4,random_state=42)

array_night = []
dir_night = os.listdir('/content/gdrive/My Drive/Alexnet/img2/night')
pattern = "night_straight*.jpg"
for filename in dir_night:
  if fnmatch.fnmatch(filename,pattern):
    array_night.append(filename)
straight_train_night,straight_val_night = train_test_split(array_night,test_size = 0.4,random_state=42)

array_mitchell = []
dir_mitchell = os.listdir('/content/gdrive/My Drive/Alexnet/img2/mitchell')
pattern = "mitchell_straight*.jpg"
for filename in dir_mitchell:
  if fnmatch.fnmatch(filename,pattern):
    array_mitchell.append(filename)
straight_train_mitchell,straight_val_mitchell = train_test_split(array_mitchell,test_size = 0.4,random_state=42)

array_megak = []
dir_megak = os.listdir('/content/gdrive/My Drive/Alexnet/img2/megak')
pattern = "megak_straight*.jpg"
for filename in dir_megak:
  if fnmatch.fnmatch(filename,pattern):
    array_megak.append(filename)
straight_train_megak,straight_val_megak = train_test_split(array_megak,test_size = 0.4,random_state=42)

array_kk49 = []
dir_kk49 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kk49')
pattern = "kk49_straight*.jpg"
for filename in dir_kk49:
  if fnmatch.fnmatch(filename,pattern):
    array_kk49.append(filename)
straight_train_kk49,straight_val_kk49 = train_test_split(array_kk49,test_size = 0.4,random_state=42)

array_kawamura = []
dir_kawamura = os.listdir('/content/gdrive/My Drive/Alexnet/img2/kawamura')
pattern = "kawamura_straight*.jpg"
for filename in dir_kawamura:
  if fnmatch.fnmatch(filename,pattern):
    array_kawamura.append(filename)
straight_train_kawamura,straight_val_kawamura = train_test_split(array_kawamura,test_size = 0.4,random_state=42)

array_karyadi = []
dir_karyadi = os.listdir('/content/gdrive/My Drive/Alexnet/img2/karyadi')
pattern = "karyadi_straight*.jpg"
for filename in dir_karyadi:
  if fnmatch.fnmatch(filename,pattern):
    array_karyadi.append(filename)
straight_train_karyadi,straight_val_karyadi = train_test_split(array_karyadi,test_size = 0.4,random_state=42)

array_glickman = []
dir_glickman = os.listdir('/content/gdrive/My Drive/Alexnet/img2/glickman')
pattern = "glickman_straight*.jpg"
for filename in dir_glickman:
  if fnmatch.fnmatch(filename,pattern):
    array_glickman.append(filename)
straight_train_glickman,straight_val_glickman = train_test_split(array_glickman,test_size = 0.4,random_state=42)

array_danieln = []
dir_danieln = os.listdir('/content/gdrive/My Drive/Alexnet/img2/danieln')
pattern = "danieln_straight*.jpg"
for filename in dir_danieln:
  if fnmatch.fnmatch(filename,pattern):
    array_danieln.append(filename)
straight_train_danieln,straight_val_danieln = train_test_split(array_danieln,test_size = 0.4,random_state=42)

array_choon = []
dir_choon = os.listdir('/content/gdrive/My Drive/Alexnet/img2/choon')
pattern = "choon_straight*.jpg"
for filename in dir_choon:
  if fnmatch.fnmatch(filename,pattern):
    array_choon.append(filename)
straight_train_choon,straight_val_choon = train_test_split(array_choon,test_size = 0.4,random_state=42)

array_cheyer = []
dir_cheyer = os.listdir('/content/gdrive/My Drive/Alexnet/img2/cheyer')
pattern = "cheyer_straight*.jpg"
for filename in dir_cheyer:
  if fnmatch.fnmatch(filename,pattern):
    array_cheyer.append(filename)
straight_train_cheyer,straight_val_cheyer = train_test_split(array_cheyer,test_size = 0.4,random_state=42)

array_ch4f = []
dir_ch4f = os.listdir('/content/gdrive/My Drive/Alexnet/img2/ch4f')
pattern = "ch4f_straight*.jpg"
for filename in dir_ch4f:
  if fnmatch.fnmatch(filename,pattern):
    array_ch4f.append(filename)
straight_train_ch4f,straight_val_ch4f = train_test_split(array_ch4f,test_size = 0.4,random_state=42)

array_bpm = []
dir_bpm = os.listdir('/content/gdrive/My Drive/Alexnet/img2/bpm')
pattern = "bpm_straight*.jpg"
for filename in dir_bpm:
  if fnmatch.fnmatch(filename,pattern):
    array_bpm.append(filename)
straight_train_bpm,straight_val_bpm = train_test_split(array_bpm,test_size = 0.4,random_state=42)

array_boland = []
dir_boland = os.listdir('/content/gdrive/My Drive/Alexnet/img2/boland')
pattern = "boland_straight*.jpg"
for filename in dir_boland:
  if fnmatch.fnmatch(filename,pattern):
    array_boland.append(filename)
straight_train_boland,straight_val_boland = train_test_split(array_boland,test_size = 0.4,random_state=42)

array_at33 = []
dir_at33 = os.listdir('/content/gdrive/My Drive/Alexnet/img2/at33')
pattern = "at33_straight*.jpg"
for filename in dir_at33:
  if fnmatch.fnmatch(filename,pattern):
    array_at33.append(filename)
straight_train_at33,straight_val_at33 = train_test_split(array_at33,test_size = 0.4,random_state=42)

array_an2i = []
dir_an2i = os.listdir('/content/gdrive/My Drive/Alexnet/img2/an2i')
pattern = "an2i_straight*.jpg"
for filename in dir_an2i:
  if fnmatch.fnmatch(filename,pattern):
    array_an2i.append(filename)
straight_train_an2i,straight_val_an2i = train_test_split(array_an2i,test_size = 0.4,random_state=42)

# %%
for i in straight_train_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(train_dir + '/straight_train', i))
for i in straight_train_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(train_dir + '/straight_train', i))

# %%
for i in straight_val_tammo:
     shutil.copy(os.path.join(data_dir + '/tammo', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_sz24:
     shutil.copy(os.path.join(data_dir + '/sz24', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_steffi:
     shutil.copy(os.path.join(data_dir + '/steffi', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_saavik:
     shutil.copy(os.path.join(data_dir + '/saavik', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_phoebe:
     shutil.copy(os.path.join(data_dir + '/phoebe', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_night:
     shutil.copy(os.path.join(data_dir + '/night', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_mitchell:
     shutil.copy(os.path.join(data_dir + '/mitchell', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_megak:
     shutil.copy(os.path.join(data_dir + '/megak', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_kk49:
     shutil.copy(os.path.join(data_dir + '/kk49', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_kawamura:
     shutil.copy(os.path.join(data_dir + '/kawamura', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_karyadi:
     shutil.copy(os.path.join(data_dir + '/karyadi', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_glickman:
     shutil.copy(os.path.join(data_dir + '/glickman', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_danieln:
     shutil.copy(os.path.join(data_dir + '/danieln', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_choon:
     shutil.copy(os.path.join(data_dir + '/choon', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_cheyer:
     shutil.copy(os.path.join(data_dir + '/cheyer', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_ch4f:
     shutil.copy(os.path.join(data_dir + '/ch4f', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_bpm:
     shutil.copy(os.path.join(data_dir + '/bpm', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_boland:
     shutil.copy(os.path.join(data_dir + '/boland', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_at33:
     shutil.copy(os.path.join(data_dir + '/at33', i), os.path.join(val_dir + '/straight_val', i))
for i in straight_val_an2i:
     shutil.copy(os.path.join(data_dir + '/an2i', i), os.path.join(val_dir + '/straight_val', i))
